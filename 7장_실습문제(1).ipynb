# %%
import pandas as pd

df=pd.read_csv('서울일자리센터 인재정보 직종별, 지역별 목록.csv',encoding='cp949')
df
# Out:
# c:\users\flora\anaconda3\envs\seun\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\flora\anaconda3\envs\seun\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\users\flora\anaconda3\envs\seun\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# c:\users\flora\anaconda3\envs\seun\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1     H309202107071965  남  87  J00100    관계없음           서울            강북구
# 2     H110202107071953  여  68  J00100    관계없음           서울            서초구
# 3     H318202107071951  남  30  J00106    고등학교           서울            금천구
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1356 entries, 0 to 1355
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   구직신청번호          1356 non-null   object
#  1   성별              1356 non-null   object
#  2   나이              1356 non-null   int64
#  3   학력공통코드          1356 non-null   object
#  4   학력공통코드명         1356 non-null   object
#  5   희망근무지역(시도)_1    1341 non-null   object
#  6   희망근무지역명(시군구)_1  1201 non-null   object
#  7   희망근무지역명(시도)_2   1136 non-null   object
#  8   희망근무지역명(시군구)_2  448 non-null    object
#  9   희망직종공통코드        1356 non-null   int64
#  10  희망직종공통코드명       1356 non-null   object
#  11  희망직종경력년수        801 non-null    float64
#  12  희망직종경력개월수       801 non-null    float64
#  13  희망직종경력년_월수      1356 non-null   object
#  14  구직인증상태공통구분      1356 non-null   object
#  15  구직인증상태공통구분명     1356 non-null   object
#  16  검색키워드1          204 non-null    object
# ...

# %% [markdown]
# ### 1. 검색키워드1에서 검색키워드5까지는 필요가 없어 보인다. 이 5개의 해당 컬럼을 삭제하시오.

# %%
df = df.drop(df.columns[[range(16, 21)]], axis = 1)
df
# Out:
# c:\users\flora\anaconda3\envs\seun\lib\site-packages\pandas\core\indexes\base.py:4616: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 희망근무지역(시도)_1 희망근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교           서울            강북구
# 1     H309202107071965  남  87  J00100    관계없음           서울            강북구
# 2     H110202107071953  여  68  J00100    관계없음           서울            서초구
# 3     H318202107071951  남  30  J00106    고등학교           서울            금천구
# 4     H129202107071950  여  66  J00106    고등학교           서울            송파구
# ...                ... ..  ..     ...     ...          ...            ...
# 1351  H001202104121072  여  54  J00102    초등학교           서울            도봉구
# ...

# %% [markdown]
# ### 2. 아래 해당 컬럼 이름을 바꾸시오.
#   '희망근무지역(시도)_1' - > '근무지역(시도)_1',
#   '희망근무지역명(시군구)_1' - > '근무지역명(시군구)_1',
#   ' 희망근무지역명(시도)_2' - > '근무지역명(시도)_2',
#   '희망근무지역명(시군구)_2' - > '근무지역명(시군구)_2',
#   '희망직종공통코드' - > '공통코드',
#   '희망직종공통코드명' - > '공통코드명',
#   '희망직종경력년수' - >'경력년수',
#   '희망직종경력개월수' - > '경력개월수',
#   '희망직종경력년_월수' - > '경력년_월수',

# %%
df.rename(columns = {'희망근무지역(시도)_1' : '근무지역(시도)_1'}, inplace = True)

# %%
df.rename(columns = {'희망근무지역명(시군구)_1' : '근무지역명(시군구)_1'}, inplace = True)

# %%
df.rename(columns = {'희망근무지역명(시도)_2' : '근무지역명(시군구)_2'}, inplace = True)

# %%
df.rename(columns = {'희망직종공통코드' : '공통코드'}, inplace = True)

# %%
df.rename(columns = {'희망직종공통코드명' : '공통코드명'}, inplace = True)

# %%
df.rename(columns = {'희망직종경력년수' : '경력년수'}, inplace = True)

# %%
df
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교         서울          강북구
# 1     H309202107071965  남  87  J00100    관계없음         서울          강북구
# 2     H110202107071953  여  68  J00100    관계없음         서울          서초구
# 3     H318202107071951  남  30  J00106    고등학교         서울          금천구
# 4     H129202107071950  여  66  J00106    고등학교         서울          송파구
# ...                ... ..  ..     ...     ...        ...          ...
# 1351  H001202104121072  여  54  J00102    초등학교         서울          도봉구
# 1352  H310202104090587  여  61  J00104     중학교         서울          도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교         서울           전체
# 1354  H001202101250036  여  47  J00108    전문대학         서울          노원구
# 1355  H001202101182829  여  23  J00108    전문대학         경기          NaN
#
#      근무지역명(시군구)_2 희망근무지역명(시군구)_2    공통코드                            공통코드명  \
# ...

# %% [markdown]
# ### 3. 이래의 사전 데이터를 활용하고, rename()을 이용하여 해당 컬럼 이름을 변경하시오.
# col_name_change = {
#     '희망근무지역(시도)_1':'근무지역(시도)_1',
#     '희망근무지역명(시군구)_1':'근무지역명(시군구)_1',
#     '희망근무지역명(시도)_2':'근무지역명(시도)_2',
#     '희망근무지역명(시군구)_2':'근무지역명(시군구)_2',
#     '희망직종공통코드':'공통코드',
#     '희망직종공통코드명':'공통코드명',
#     '희망직종경력년수':'경력년수',
#     '희망직종경력개월수':'경력개월수',
#     '희망직종경력년_월수':'경력년_월수',
# }

# %%
col_name_change = {
    '희망근무지역(시도)_1':'근무지역(시도)_1',
    '희망근무지역명(시군구)_1':'근무지역명(시군구)_1',
    '희망근무지역명(시도)_2':'근무지역명(시도)_2',
    '희망근무지역명(시군구)_2':'근무지역명(시군구)_2',
    '희망직종공통코드':'공통코드',
    '희망직종공통코드명':'공통코드명',
    '희망직종경력년수':'경력년수',
    '희망직종경력개월수':'경력개월수',
    '희망직종경력년_월수':'경력년_월수',
}

# %%
df.rename(columns = col_name_change, inplace = True)
df
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교         서울          강북구
# 1     H309202107071965  남  87  J00100    관계없음         서울          강북구
# 2     H110202107071953  여  68  J00100    관계없음         서울          서초구
# 3     H318202107071951  남  30  J00106    고등학교         서울          금천구
# 4     H129202107071950  여  66  J00106    고등학교         서울          송파구
# ...                ... ..  ..     ...     ...        ...          ...
# 1351  H001202104121072  여  54  J00102    초등학교         서울          도봉구
# 1352  H310202104090587  여  61  J00104     중학교         서울          도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교         서울           전체
# 1354  H001202101250036  여  47  J00108    전문대학         서울          노원구
# 1355  H001202101182829  여  23  J00108    전문대학         경기          NaN
#
#      근무지역명(시군구)_2 근무지역명(시군구)_2    공통코드                            공통코드명  경력년수  \
# ...

# %% [markdown]
# ### 4. df 데이터 프레임에는 NaN값이 존재한다. NaN 값을 '없음'으로 변경하여 채우시오.
#      (a) fillna 사용하여 채우기
#      (b) replace 사용하여 채우기

# %%
df.fillna('없음')
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교         서울          강북구
# 1     H309202107071965  남  87  J00100    관계없음         서울          강북구
# 2     H110202107071953  여  68  J00100    관계없음         서울          서초구
# 3     H318202107071951  남  30  J00106    고등학교         서울          금천구
# 4     H129202107071950  여  66  J00106    고등학교         서울          송파구
# ...                ... ..  ..     ...     ...        ...          ...
# 1351  H001202104121072  여  54  J00102    초등학교         서울          도봉구
# 1352  H310202104090587  여  61  J00104     중학교         서울          도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교         서울           전체
# 1354  H001202101250036  여  47  J00108    전문대학         서울          노원구
# 1355  H001202101182829  여  23  J00108    전문대학         경기           없음
#
#      근무지역명(시군구)_2 근무지역명(시군구)_2    공통코드                            공통코드명  경력년수  \
# ...

# %%
import numpy as np

# %%
df
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 0     H128202107071973  남  74  J00106    고등학교         서울          강북구
# 1     H309202107071965  남  87  J00100    관계없음         서울          강북구
# 2     H110202107071953  여  68  J00100    관계없음         서울          서초구
# 3     H318202107071951  남  30  J00106    고등학교         서울          금천구
# 4     H129202107071950  여  66  J00106    고등학교         서울          송파구
# ...                ... ..  ..     ...     ...        ...          ...
# 1351  H001202104121072  여  54  J00102    초등학교         서울          도봉구
# 1352  H310202104090587  여  61  J00104     중학교         서울          도봉구
# 1353  H001202101250403  여  47  J00110  대학_대학교         서울           전체
# 1354  H001202101250036  여  47  J00108    전문대학         서울          노원구
# 1355  H001202101182829  여  23  J00108    전문대학         경기          NaN
#
#      근무지역명(시군구)_2 근무지역명(시군구)_2    공통코드                            공통코드명  경력년수  \
# ...

# %%
df = df.replace(np.nan, '없음')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1356 entries, 0 to 1355
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   구직신청번호        1356 non-null   object
#  1   성별            1356 non-null   object
#  2   나이            1356 non-null   int64
#  3   학력공통코드        1356 non-null   object
#  4   학력공통코드명       1356 non-null   object
#  5   근무지역(시도)_1    1356 non-null   object
#  6   근무지역명(시군구)_1  1356 non-null   object
#  7   근무지역명(시군구)_2  1356 non-null   object
#  8   근무지역명(시군구)_2  1356 non-null   object
#  9   공통코드          1356 non-null   int64
#  10  공통코드명         1356 non-null   object
#  11  경력년수          1356 non-null   object
#  12  경력개월수         1356 non-null   object
#  13  경력년_월수        1356 non-null   object
#  14  구직인증상태공통구분    1356 non-null   object
#  15  구직인증상태공통구분명   1356 non-null   object
#  16  등록일시          1356 non-null   object
#  17  수정일시          1356 non-null   object
# ...

# %%
df[df['경력년수']==0]
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 5     H108202107071928  여  63  J00106    고등학교         서울         서대문구
# 22    H317202107071828  여  57  J00106    고등학교         서울          구로구
# 50    H322202107071685  남  64  J00110  대학_대학교         서울         영등포구
# 73    H319202107071563  남  57  J00106    고등학교         서울         영등포구
# 104   H316202107071426  남  70  J00104     중학교         서울          강서구
# ...                ... ..  ..     ...     ...        ...          ...
# 1343  H001202104250506  여  25  J00110  대학_대학교         서울           전체
# 1344  H001202104240307  여  23  J00110  대학_대학교         서울           전체
# 1347  H001202104200022  여  25  J00110  대학_대학교         서울           전체
# 1348  H001202104192122  남  30  J00110  대학_대학교       지역무관         지역무관
# 1351  H001202104121072  여  54  J00102    초등학교         서울          도봉구
#
#      근무지역명(시군구)_2 근무지역명(시군구)_2    공통코드                       공통코드명 경력년수 경력개월수  \
# ...

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
axis1 = fig.add_subplot(1, 1, 1)

axis1.hist(df['성별'])
plt.show()

# %%
female = df[df['성별']=='여']

# %%
male = df[df['성별']=='남']

# %%
df[df['나이'] <20]
# Out:
#                 구직신청번호 성별  나이  학력공통코드 학력공통코드명 근무지역(시도)_1 근무지역명(시군구)_1  \
# 379   H001202107062256  남  18  J00106    고등학교         서울          성북구
# 430   H316202107061875  남  18  J00106    고등학교         서울          강서구
# 434   H316202107061830  남  17  J00106    고등학교         서울          강서구
# 438   H316202107061826  남  17  J00106    고등학교         서울          강서구
# 550   H316202107061268  남  17  J00106    고등학교         서울          강서구
# 1309  H001202106100188  남  19  J00106    고등학교       지역무관         지역무관
#
#      근무지역명(시군구)_2 근무지역명(시군구)_2    공통코드                   공통코드명 경력년수 경력개월수  \
# 379            서울           없음   26101               경영 기획 사무원   없음    없음
# 430            서울           없음  834000            전기?전자 설비 조작원   없음    없음
# 434            서울           없음  834000            전기?전자 설비 조작원   없음    없음
# 438            서울           없음  834000            전기?전자 설비 조작원   없음    없음
# 550            서울           없음  834000            전기?전자 설비 조작원   없음    없음
# ...
