# %%
import numpy as np
import librosa as lbr
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy import signal as sp
plt.rc('font', family='Malgun Gothic')

# %%
from scipy.io import wavfile
fs, x = wavfile.read("C:/Users/Flora/Documents/이세은/2-2교과목/디지털신호처리/붙임3. NOISY_INPUT_DB/airport/0dB/sp01_airport_sn0.wav")

# %%
print('입력신호')
display(ipd.Audio(x, rate = fs))
# Out:
# 입력신호
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(12,4))
plt.plot(x)
plt.xlabel('샘플')
plt.ylabel('값')
plt.title('입력신호 파형')
plt.grid()
# Out:
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.specgram(x)
plt.title('입력신호 스펙트로그램')
plt.show()

# %%
data = np.zeros(len(x))
for i in range(0,len(x),50):
    x_ = x[i:i+100]
    x_w = x_ * np.hamming(len(x_))
    x_fft = np.fft.fft(x_w)
    x_fft[abs(x_fft) < 4000] /= x_fft[abs(x_fft) < 4000]**2 # 윈도윙 후 잡음 제거 방법 개선 필요
    x_ifft = np.fft.ifft(x_fft)
    data[i:i+100] += x_ifft.real
data
# Out:
# array([ -53.95727751,   43.429791  ,  -64.03842161, ...,  -28.55706158,
#        -195.1912317 ,  -96.75356959])

# %%
y, sr = librosa.load("C:/Users/Flora/Documents/이세은/2-2교과목/디지털신호처리/붙임3. NOISY_INPUT_DB/airport/0dB/sp01_airport_sn0.wav")
ft = librosa.stft(y)

# %%
maiden_filtered = sp.wiener(x, mysize=5)
display(ipd.Audio(maiden_filtered, rate = sr ))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('출력신호')
display(ipd.Audio(data, rate = fs))
# Out:
# 출력신호
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(8,4))
plt.plot(data)
plt.xlabel('샘플')
plt.ylabel('값')
plt.title('출력신호 파형')
plt.grid()
# Out:
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.specgram(data)
plt.title('출력신호 스펙트로그램')
plt.show()

# %%
fs2, x2 = wavfile.read("C:/Users/Flora/Documents/이세은/2-2교과목/디지털신호처리/붙임3. NOISY_INPUT_DB/airport/15dB/sp01_airport_sn15.wav")

# %%
print('입력신호2')
display(ipd.Audio(x2, rate = fs2))
# Out:
# 입력신호2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(8,4))
plt.plot(x2)
plt.xlabel('샘플')
plt.ylabel('값')
plt.title('입력신호2 파형')
plt.grid()
# Out:
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.specgram(x2)
plt.title('입력신호2 스펙트로그램')
plt.show()

# %%
data2 = np.zeros(len(x2))
for i in range(0,len(x2),50):
    x2_ = x2[i:i+100]
    x2_w = x2_ * np.hamming(len(x2_))
    x2_fft = np.fft.fft(x2_w)
    x2_fft[abs(x2_fft) < 4000] /= x2_fft[abs(x2_fft) < 4000]**2 # 윈도윙 후 잡음 제거 방법 개선 필요
    x2_ifft = np.fft.ifft(x2_fft)
    data2[i:i+100] += x2_ifft.real
data2
# Out:
# array([-2.65549632e+01, -2.05337912e+01, -1.08430844e+01, ...,
#        -2.50159367e-02,  1.65118909e-02, -1.57816831e-02])

# %%
print('출력신호2')
display(ipd.Audio(data2, rate = fs2))
# Out:
# 출력신호2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(8,4))
plt.plot(data2)
plt.xlabel('샘플')
plt.ylabel('값')
plt.title('출력신호2 파형')
plt.grid()
# Out:
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Flora\anaconda3\envs\seun\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.specgram(data2)
plt.title('출력신호2 스펙트로그램')
plt.show()

# %%
from scipy import signal as sp
import numpy as np
import IPython.display as ipd
import librosa as lbr
import wave
import struct
