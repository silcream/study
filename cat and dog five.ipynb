# %%
import sys

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("./dog-vs-cat-classification"))
# Out:
# ['sample_submission.csv', 'test', 'train']

# %%
FAST_RUN = False
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# %%
filenames = os.listdir('./dog-vs-cat-classification/train')
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)
        
df = pd.DataFrame({
    'filename' : filenames,
    'category' : categories
})

# %%
df.head()
# Out:
#        filename  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %%
df.tail()
# Out:
#            filename  category
# 24997  dog.9996.jpg         1
# 24998  dog.9997.jpg         1
# 24999  dog.9998.jpg         1
# 25000  dog.9999.jpg         1
# 25001          dogs         0

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
random.seed(2022)

sample = random.choice(filenames)
image = load_img("./dog-vs-cat-classification/train/"+sample)
plt.imshow(image)
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

# model = Sequential([
#     # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
#     Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
#     MaxPooling2D(2, 2), 
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2), 
#     Conv2D(128, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2), 
#     Conv2D(128, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2), 
#     # 2D -> 1D로 변환을 위하여 Flatten 합니다.
#     Flatten(), 
#     # 과적합 방지를 위하여 Dropout을 적용합니다.
#     Dropout(0.5),
#     Dense(512, activation='relu'),
#     # Classification을 위한 Softmax 
#     # 출력층의 갯수는 클래스의 갯수와 동일하게 맞춰줍니다 (3개), activation도 잊지마세요!
#     Dense(3, activation='softmax'),
# ])

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape = (IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 2,605,122
# Trainable params: 2,603,394
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(patience = 7)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_acc',
                                           patience = 2,
                                           verbose = 1,
                                           factor = 0.5,
                                           min_lr = 0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
df['category'] = df['category'].replace({0: 'cat', 1:'dog'})

# %%
# train - validation 데이터 분리

train_df, validate_df = train_test_split(df, test_size = 0.2, random_state = 42)
train_df = train_df.reset_index(drop = True)
validate_df = validate_df.reset_index(drop = True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 20

# %%
train_datagen = ImageDataGenerator(
    rotation_range = 15,
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    './dog-vs-cat-classification/train',
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 19999 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    './dog-vs-cat-classification/train',
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 5001 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop = True)
example_generator = train_datagen.flow_from_dataframe(
    example_df,
    './dog-vs-cat-classification/train',
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
epochs = 3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,
    steps_per_epoch = total_train//batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001C322847C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001C322847C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.6568WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001C3333013A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001C3333013A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 78s 75ms/step - loss: 0.6936 - accuracy: 0.6568 - val_loss: 0.6562 - val_accuracy: 0.6948 - lr: 0.0010
# Epoch 2/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.5112 - accuracy: 0.7503WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.5112 - accuracy: 0.7503 - val_loss: 0.4327 - val_accuracy: 0.8012 - lr: 0.0010
# Epoch 3/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.4382 - accuracy: 0.7947WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.4382 - accuracy: 0.7947 - val_loss: 0.3672 - val_accuracy: 0.8314 - lr: 0.0010
# Epoch 4/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8232WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.3895 - accuracy: 0.8232 - val_loss: 0.2870 - val_accuracy: 0.8736 - lr: 0.0010
# Epoch 5/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8433WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.3574 - accuracy: 0.8433 - val_loss: 0.4897 - val_accuracy: 0.7742 - lr: 0.0010
# Epoch 6/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3351 - accuracy: 0.8534WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.3351 - accuracy: 0.8534 - val_loss: 0.2988 - val_accuracy: 0.8686 - lr: 0.0010
# Epoch 7/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8571WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.3253 - accuracy: 0.8571 - val_loss: 0.2492 - val_accuracy: 0.9012 - lr: 0.0010
# Epoch 8/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8706WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.3020 - accuracy: 0.8706 - val_loss: 0.2368 - val_accuracy: 0.9022 - lr: 0.0010
# Epoch 9/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.8778WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2922 - accuracy: 0.8778 - val_loss: 0.2982 - val_accuracy: 0.8698 - lr: 0.0010
# Epoch 10/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 0.8781WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2923 - accuracy: 0.8781 - val_loss: 0.2362 - val_accuracy: 0.9096 - lr: 0.0010
# Epoch 11/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8820WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2817 - accuracy: 0.8820 - val_loss: 0.1904 - val_accuracy: 0.9182 - lr: 0.0010
# Epoch 12/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.8833WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2734 - accuracy: 0.8833 - val_loss: 0.1936 - val_accuracy: 0.9252 - lr: 0.0010
# Epoch 13/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.8894WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2713 - accuracy: 0.8894 - val_loss: 0.2676 - val_accuracy: 0.8892 - lr: 0.0010
# Epoch 14/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2698 - accuracy: 0.8880WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2698 - accuracy: 0.8880 - val_loss: 0.1945 - val_accuracy: 0.9244 - lr: 0.0010
# Epoch 15/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8908WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2653 - accuracy: 0.8908 - val_loss: 0.2451 - val_accuracy: 0.8926 - lr: 0.0010
# Epoch 16/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.8929WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2599 - accuracy: 0.8929 - val_loss: 0.1649 - val_accuracy: 0.9324 - lr: 0.0010
# Epoch 17/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.8979WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2500 - accuracy: 0.8979 - val_loss: 0.1917 - val_accuracy: 0.9200 - lr: 0.0010
# Epoch 18/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.8974WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2458 - accuracy: 0.8974 - val_loss: 0.2859 - val_accuracy: 0.8784 - lr: 0.0010
# Epoch 19/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9001WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2445 - accuracy: 0.9001 - val_loss: 0.2402 - val_accuracy: 0.8920 - lr: 0.0010
# Epoch 20/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.8996WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.2469 - accuracy: 0.8996 - val_loss: 0.2542 - val_accuracy: 0.9012 - lr: 0.0010
# Epoch 21/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9013WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2409 - accuracy: 0.9013 - val_loss: 0.2014 - val_accuracy: 0.9178 - lr: 0.0010
# Epoch 22/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9043WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2344 - accuracy: 0.9043 - val_loss: 0.1978 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 23/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9060WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1000/1000 [==============================] - 75s 75ms/step - loss: 0.2292 - accuracy: 0.9060 - val_loss: 0.1708 - val_accuracy: 0.9346 - lr: 0.0010

# %%
model.save_weights('model5.h5')

# %%
# 학습 내용 확인

fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 12))
ax1.plot(history.history['loss'], color = 'b', label = 'Training loss')
ax1.plot(history.history['val_loss'], color = 'r', label = 'validation loss')
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color = 'b', label = 'Training accuracy')
ax2.plot(history.history['val_accuracy'], color = 'r', label = 'Validation accuracy')
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc = 'best', shadow = True)
plt.tight_layout()
plt.show()
