# %%
print('*********************************************')
print('Hello! I will introduce myself')
print('Address : Changwon, Republic of Korea')
print('Age : 22')
print(' Birthplace : Masan, Republic of Korea')
print('Job : Software Engineer')
print('*********************************************')
# Out:
# *********************************************
# Hello! I will introduce myself
# Address : Changwon, Republic of Korea
# Age : 22
#  Birthplace : Masan, Republic of Korea
# Job : Software Engineer
# *********************************************

# %%
import matplotlib.pyplot as plt
from PIL import Image

import warnings
warnings.filterwarnings('ignore')

# %%
image = Image.open('C:/Users/Flora/Pictures/pink.jpg')

# %%
print('My pink cloud')
plt.imshow(image)
plt.show()
# Out:
# My pink cloud

# %%
import pandas as pd

df = pd.read_csv('C:/Users/Flora/3-1교과목 머신러닝/DataML-main/csv/game_usage.csv')
df.head()
# Out:
#    time spent  game level
# 0          39         944
# 1          55         705
# 2          29         757
# 3          59         999
# 4           7         109
